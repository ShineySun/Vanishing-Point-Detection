# %%
# !ls
# Out:
# lstm_ver2.ipynb  mnist_lstm.py

# %%
import json

# %%
# Tusimple Dataset Management Tool
class Tusimple_Manager(object):
    # initialize
    def __init__(self, root_dir = '/home/sun/tusimple'):
        # train data root path
        self.train_path = root_dir + '/train_set/'
        # test data root path
        self.test_path = root_dir + '/test_set/'
        # train data annotation files
        self.train_label_files = ['label_data_0313.json' , 'label_data_0531.json' , 'label_data_0601.json']
        # test data annotation files
        self.test_label_files = ['test_label.json']

        # train annotation data
        self.train_data = []
        # train data size
        self.train_size = 0
        # test annotation data
        self.test_data = []
        # test data size
        self.test_size = 0

        # number of train_instance 1
        self.train_instance_1 = []
        # number of train_instance 2
        self.train_instance_2 = []
        # number of train_instance 3
        self.train_instance_3 = []
        # number of train_instance 4
        self.train_instance_4 = []
        # number of train_instance 5
        self.train_instance_5 = []
        # number of train_instance 6
        self.train_instance_6 = []


        # number of test_instance 1
        self.test_instance_1 = []
        # number of test_instance 2
        self.test_instance_2 = []
        # number of test_instance 3
        self.test_instance_3 = []
        # number of test_instance 4
        self.test_instance_4 = []
        # number of test_instance 5
        self.test_instance_5 = []
        # number of test_instance 6
        self.test_instance_6 = []

    # load the data
    def tusimple_load_from_json(self):
        # train data load
        print("* Train Data Load Start")
        for idx, label_file in enumerate(self.train_label_files):
            # print("* {} : {} Load Start".format(idx, label_file))

            with open(self.train_path + label_file) as f:
                for line in f.readlines():
                    json_line = json.loads(line)
                    self.train_data.append(json_line)

            # print("* {} : {} Load Finish".format(idx, label_file))
        self.train_size = len(self.train_data)

        print("* Train Data Load Finish")

        # test data load
        print("* Test Data Load Start")

        for idx, label_file in enumerate(self.test_label_files):
            # print("* {} : {} Load Start".format(idx, label_file))

            with open(self.test_path + label_file) as f:
                for line in f.readlines():
                    json_line = json.loads(line)
                    self.test_data.append(json_line)

        self.test_size = len(self.test_data)

        print("* Test Data Load Finish")

    # split according to the number of instances
    def tusimple_split_instance(self):
        print("**-----------------------------------------------**")
        print("* Train Data Split Start")
        # train data split
        for idx,instance in enumerate(self.train_data):
            if len(instance['lanes']) == 1:
                self.train_instance_1.append(instance)
            elif len(instance['lanes']) == 2:
                self.train_instance_2.append(instance)
            elif len(instance['lanes']) == 3:
                self.train_instance_3.append(instance)
            elif len(instance['lanes']) == 4:
                self.train_instance_4.append(instance)
            elif len(instance['lanes']) == 5:
                self.train_instance_5.append(instance)
            elif len(instance['lanes']) == 6:
                self.train_instance_6.append(instance)


        print("num_train_instance_1 : {}".format(len(self.train_instance_1)))
        print("num_train_instance_2 : {}".format(len(self.train_instance_2)))
        print("num_train_instance_3 : {}".format(len(self.train_instance_3)))
        print("num_train_instance_4 : {}".format(len(self.train_instance_4)))
        print("num_train_instance_5 : {}".format(len(self.train_instance_5)))
        print("num_train_instance_6 : {}".format(len(self.train_instance_6)))


        print("* Train Data Split Finish")
        print("**-----------------------------------------------**")

        print("* Test Data Split Start")

        # test data split
        for idx,instance in enumerate(self.test_data):
            if len(instance['lanes']) == 1:
                self.test_instance_1.append(instance)
            elif len(instance['lanes']) == 2:
                self.test_instance_2.append(instance)
            elif len(instance['lanes']) == 3:
                self.test_instance_3.append(instance)
            elif len(instance['lanes']) == 4:
                self.test_instance_4.append(instance)
            elif len(instance['lanes']) == 5:
                self.test_instance_5.append(instance)
            elif len(instance['lanes']) == 6:
                self.test_instance_6.append(instance)

        print("num_test_instance_1 : {}".format(len(self.test_instance_1)))
        print("num_test_instance_2 : {}".format(len(self.test_instance_2)))
        print("num_test_instance_3 : {}".format(len(self.test_instance_3)))
        print("num_test_instance_4 : {}".format(len(self.test_instance_4)))
        print("num_test_instance_5 : {}".format(len(self.test_instance_5)))
        print("num_test_instance_6 : {}".format(len(self.test_instance_6)))

        print("* Test Data Split Finish")

        print("**-----------------------------------------------**")

# %%
tusimple_manager = Tusimple_Manager()

# %%
tusimple_manager.tusimple_load_from_json()
# Out:
# * Train Data Load Start
# * Train Data Load Finish
# * Test Data Load Start
# * Test Data Load Finish

# %%
tusimple_manager.tusimple_split_instance()
# Out:
# **-----------------------------------------------**
# * Train Data Split Start
# num_train_instance_1 : 0
# num_train_instance_2 : 1
# num_train_instance_3 : 404
# num_train_instance_4 : 2982
# num_train_instance_5 : 239
# num_train_instance_6 : 0
# * Train Data Split Finish
# **-----------------------------------------------**
# * Test Data Split Start
# num_test_instance_1 : 0
# num_test_instance_2 : 5
# num_test_instance_3 : 1740
# num_test_instance_4 : 468
# num_test_instance_5 : 569
# num_test_instance_6 : 0
# * Test Data Split Finish
# **-----------------------------------------------**

# %%
print(tusimple_manager.train_instance_2)
# Out:
# [{'lanes': [[-2, -2, -2, -2, -2, -2, -2, 802, 748, 713, 688, 663, 639, 620, 600, 580, 560, 541, 521, 503, 488, 474, 459, 444, 429, 414, 399, 384, 369, 354, 339, 324, 309, 294, 279, 264, 250, 235, 220, 205, 190, 175, 160, 145, 130, 115, 100, 85, 70, 55, 40, 26, 11, -2, -2, -2], [-2, -2, -2, -2, -2, -2, -2, -2, 841, 814, 808, 801, 795, 798, 801, 804, 807, 810, 814, 820, 826, 832, 839, 845, 852, 860, 868, 876, 884, 892, 900, 908, 915, 923, 931, 939, 947, 955, 963, 970, 978, 986, 994, 1002, 1010, 1018, 1026, 1033, 1041, 1049, 1057, 1065, 1073, 1081, 1088, 1096]], 'h_samples': [160, 170, 180, 190, 200, 210, 220, 230, 240, 250, 260, 270, 280, 290, 300, 310, 320, 330, 340, 350, 360, 370, 380, 390, 400, 410, 420, 430, 440, 450, 460, 470, 480, 490, 500, 510, 520, 530, 540, 550, 560, 570, 580, 590, 600, 610, 620, 630, 640, 650, 660, 670, 680, 690, 700, 710], 'raw_file': 'clips/0531/1492629882697772610/20.jpg'}]

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

train_set = None
test_set = None

for idx, instance in enumerate(tusimple_manager.train_instance_2):
    clip_dir = tusimple_manager.train_path + instance['raw_file']
    
    image = cv2.imread(clip_dir)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    plt.imshow(image)
    
    lane_arr = list(instance['lanes'])
    
    lane_arr = np.array(lane_arr)
    lane_arr = np.flip(lane_arr, axis=1)
    
    train_set = lane_arr[: , : 45]
    test_set = lane_arr[:, 45: ]
    
    print(train_set)
    print(test_set)
# Out:
# [[  -2   -2   -2   11   26   40   55   70   85  100  115  130  145  160
#    175  190  205  220  235  250  264  279  294  309  324  339  354  369
#    384  399  414  429  444  459  474  488  503  521  541  560  580  600
#    620  639  663]
#  [1096 1088 1081 1073 1065 1057 1049 1041 1033 1026 1018 1010 1002  994
#    986  978  970  963  955  947  939  931  923  915  908  900  892  884
#    876  868  860  852  845  839  832  826  820  814  810  807  804  801
#    798  795  801]]
# [[688 713 748 802  -2  -2  -2  -2  -2  -2  -2]
#  [808 814 841  -2  -2  -2  -2  -2  -2  -2  -2]]

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
mm = MinMaxScaler()
ss = StandardScaler()

# %%
train_ss = ss.fit_transform(train_set)
test_ss = ss.fit_transform(test_set)

# %%
print(len(train_ss))
print(len(test_ss))
# Out:
# 2
# 2

# %%
x_train = train_ss[:1, :]
x_test = train_ss[1:, :]

y_train = test_ss[:1, :]
y_test = test_ss[1:, :]

# %%
print("Training Shape : {} {}".format(x_train.shape,y_train.shape))
print("Test Shape : {} {}".format(x_test.shape,y_test.shape))
# Out:
# Training Shape : (1, 45) (1, 11)
# Test Shape : (1, 45) (1, 11)

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable

# %%
x_train_tensors = Variable(torch.Tensor(x_train))
x_test_tensors = Variable(torch.Tensor(x_test))

y_train_tensors = Variable(torch.Tensor(y_train))
y_test_tensors = Variable(torch.Tensor(y_test))

# %%
X_train_tensors_final = torch.reshape(x_train_tensors,   (x_train_tensors.shape[0], 1, x_train_tensors.shape[1]))


X_test_tensors_final = torch.reshape(x_test_tensors,  (x_test_tensors.shape[0], 1, x_test_tensors.shape[1]))

# %%
class LSTM1(nn.Module):
  def __init__(self, num_classes, input_size, hidden_size, num_layers, seq_length):
    super(LSTM1, self).__init__()
    self.num_classes = num_classes
    self.num_layers = num_layers
    self.input_size = input_size
    self.hidden_size = hidden_size
    self.seq_length = seq_length

    self.lstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, batch_first=True)
    self.fc_1 = nn.Linear(hidden_size, 128)
    self.fc = nn.Linear(128, num_classes)

    self.relu = nn.ReLU()
    self.sigmoid = nn.Sigmoid()

  def forward(self, x):
    h_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size))

    c_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size))

    output, (hn, cn) = self.lstm(x, (h_0, c_0))

    hn = hn.view(-1, self.hidden_size)

    out = self.sigmoid(hn)

    out = self.fc_1(out)

    out = self.relu(out)

    out = self.fc(out)

    return out[-1]

# %%
num_epochs = 10000
learning_rate = 0.001

input_size = 45
hidden_size = 11
num_layers = 10

num_classes = 1

# %%
lstm1 = LSTM1(num_classes, input_size, hidden_size, num_layers, X_train_tensors_final.shape[1]) # 1 5 2 1

# %%
criterion = torch.nn.MSELoss()    # mean-squared error for regression
optimizer = torch.optim.Adam(lstm1.parameters(), lr=learning_rate)

# %%
for epoch in range(num_epochs):
  outputs = lstm1.forward(X_train_tensors_final)
  optimizer.zero_grad()

  loss = criterion(outputs, y_train_tensors[0])

  loss.backward()

  optimizer.step()

  if epoch%10 == 0:
    print("Epoch : %d, loss : %1.5f" % (epoch, loss.item()))
# Out:
# Epoch : 0, loss : 0.79924
# Epoch : 10, loss : 0.79599
# Epoch : 20, loss : 0.79278
# Epoch : 30, loss : 0.78955
# Epoch : 40, loss : 0.78619
# Epoch : 50, loss : 0.78256
# Epoch : 60, loss : 0.77845
# Epoch : 70, loss : 0.77354
# Epoch : 80, loss : 0.76730
# Epoch : 90, loss : 0.75890
# Epoch : 100, loss : 0.74723
# Epoch : 110, loss : 0.73152
# Epoch : 120, loss : 0.71254
# Epoch : 130, loss : 0.69257
# Epoch : 140, loss : 0.67363
# Epoch : 150, loss : 0.65667
# Epoch : 160, loss : 0.64192
# Epoch : 170, loss : 0.62926
# Epoch : 180, loss : 0.61840
# Epoch : 190, loss : 0.60906
# Epoch : 200, loss : 0.60104
# Epoch : 210, loss : 0.59422
# Epoch : 220, loss : 0.58846
# Epoch : 230, loss : 0.58365
# Epoch : 240, loss : 0.57964
# Epoch : 250, loss : 0.57630
# Epoch : 260, loss : 0.57350
# Epoch : 270, loss : 0.57114
# Epoch : 280, loss : 0.56914
# Epoch : 290, loss : 0.56741
# Epoch : 300, loss : 0.56592
# Epoch : 310, loss : 0.56462
# Epoch : 320, loss : 0.56348
# Epoch : 330, loss : 0.56247
# Epoch : 340, loss : 0.56157
# Epoch : 350, loss : 0.56076
# Epoch : 360, loss : 0.56003
# Epoch : 370, loss : 0.55937
# Epoch : 380, loss : 0.55877
# Epoch : 390, loss : 0.55822
# Epoch : 400, loss : 0.55772
# Epoch : 410, loss : 0.55726
# Epoch : 420, loss : 0.55683
# Epoch : 430, loss : 0.55644
# Epoch : 440, loss : 0.55607
# Epoch : 450, loss : 0.55573
# Epoch : 460, loss : 0.55541
# Epoch : 470, loss : 0.55512
# Epoch : 480, loss : 0.55484
# Epoch : 490, loss : 0.55458
# Epoch : 500, loss : 0.55433
# Epoch : 510, loss : 0.55410
# Epoch : 520, loss : 0.55388
# Epoch : 530, loss : 0.55368
# Epoch : 540, loss : 0.55348
# Epoch : 550, loss : 0.55330
# Epoch : 560, loss : 0.55313
# Epoch : 570, loss : 0.55296
# Epoch : 580, loss : 0.55280
# Epoch : 590, loss : 0.55265
# Epoch : 600, loss : 0.55251
# Epoch : 610, loss : 0.55237
# Epoch : 620, loss : 0.55224
# Epoch : 630, loss : 0.55212
# Epoch : 640, loss : 0.55200
# Epoch : 650, loss : 0.55189
# Epoch : 660, loss : 0.55178
# Epoch : 670, loss : 0.55167
# Epoch : 680, loss : 0.55157
# Epoch : 690, loss : 0.55148
# Epoch : 700, loss : 0.55138
# Epoch : 710, loss : 0.55130
# Epoch : 720, loss : 0.55121
# Epoch : 730, loss : 0.55113
# Epoch : 740, loss : 0.55105
# Epoch : 750, loss : 0.55097
# Epoch : 760, loss : 0.55090
# Epoch : 770, loss : 0.55083
# Epoch : 780, loss : 0.55076
# Epoch : 790, loss : 0.55069
# Epoch : 800, loss : 0.55063
# Epoch : 810, loss : 0.55057
# Epoch : 820, loss : 0.55051
# Epoch : 830, loss : 0.55045
# Epoch : 840, loss : 0.55039
# Epoch : 850, loss : 0.55034
# Epoch : 860, loss : 0.55029
# Epoch : 870, loss : 0.55024
# Epoch : 880, loss : 0.55019
# Epoch : 890, loss : 0.55014
# Epoch : 900, loss : 0.55009
# Epoch : 910, loss : 0.55005
# Epoch : 920, loss : 0.55000
# Epoch : 930, loss : 0.54996
# Epoch : 940, loss : 0.54992
# Epoch : 950, loss : 0.54988
# Epoch : 960, loss : 0.54984
# Epoch : 970, loss : 0.54980
# Epoch : 980, loss : 0.54976
# Epoch : 990, loss : 0.54973
# Epoch : 1000, loss : 0.54969
# Epoch : 1010, loss : 0.54966
# Epoch : 1020, loss : 0.54963
# Epoch : 1030, loss : 0.54959
# Epoch : 1040, loss : 0.54956
# Epoch : 1050, loss : 0.54953
# Epoch : 1060, loss : 0.54950
# Epoch : 1070, loss : 0.54947
# Epoch : 1080, loss : 0.54944
# Epoch : 1090, loss : 0.54942
# Epoch : 1100, loss : 0.54939
# Epoch : 1110, loss : 0.54936
# Epoch : 1120, loss : 0.54934
# Epoch : 1130, loss : 0.54931
# Epoch : 1140, loss : 0.54929
# Epoch : 1150, loss : 0.54926
# Epoch : 1160, loss : 0.54924
# Epoch : 1170, loss : 0.54921
# Epoch : 1180, loss : 0.54919
# Epoch : 1190, loss : 0.54917
# Epoch : 1200, loss : 0.54915
# Epoch : 1210, loss : 0.54913
# Epoch : 1220, loss : 0.54911
# Epoch : 1230, loss : 0.54909
# Epoch : 1240, loss : 0.54907
# Epoch : 1250, loss : 0.54905
# Epoch : 1260, loss : 0.54903
# Epoch : 1270, loss : 0.54901
# Epoch : 1280, loss : 0.54899
# Epoch : 1290, loss : 0.54897
# Epoch : 1300, loss : 0.54895
# Epoch : 1310, loss : 0.54894
# Epoch : 1320, loss : 0.54892
# Epoch : 1330, loss : 0.54890
# Epoch : 1340, loss : 0.54889
# Epoch : 1350, loss : 0.54887
# Epoch : 1360, loss : 0.54886
# Epoch : 1370, loss : 0.54884
# Epoch : 1380, loss : 0.54883
# Epoch : 1390, loss : 0.54881
# Epoch : 1400, loss : 0.54880
# Epoch : 1410, loss : 0.54878
# Epoch : 1420, loss : 0.54877
# Epoch : 1430, loss : 0.54876
# Epoch : 1440, loss : 0.54874
# Epoch : 1450, loss : 0.54873
# Epoch : 1460, loss : 0.54872
# Epoch : 1470, loss : 0.54870
# Epoch : 1480, loss : 0.54869
# Epoch : 1490, loss : 0.54868
# Epoch : 1500, loss : 0.54867
# Epoch : 1510, loss : 0.54865
# Epoch : 1520, loss : 0.54864
# Epoch : 1530, loss : 0.54863
# Epoch : 1540, loss : 0.54862
# Epoch : 1550, loss : 0.54861
# Epoch : 1560, loss : 0.54860
# Epoch : 1570, loss : 0.54859
# Epoch : 1580, loss : 0.54858
# Epoch : 1590, loss : 0.54857
# Epoch : 1600, loss : 0.54856
# Epoch : 1610, loss : 0.54855
# Epoch : 1620, loss : 0.54854
# Epoch : 1630, loss : 0.54853
# Epoch : 1640, loss : 0.54852
# Epoch : 1650, loss : 0.54851
# Epoch : 1660, loss : 0.54850
# Epoch : 1670, loss : 0.54849
# Epoch : 1680, loss : 0.54848
# Epoch : 1690, loss : 0.54847
# Epoch : 1700, loss : 0.54846
# Epoch : 1710, loss : 0.54846
# Epoch : 1720, loss : 0.54845
# Epoch : 1730, loss : 0.54844
# Epoch : 1740, loss : 0.54843
# Epoch : 1750, loss : 0.54842
# Epoch : 1760, loss : 0.54841
# Epoch : 1770, loss : 0.54841
# Epoch : 1780, loss : 0.54840
# Epoch : 1790, loss : 0.54839
# Epoch : 1800, loss : 0.54838
# Epoch : 1810, loss : 0.54838
# Epoch : 1820, loss : 0.54837
# Epoch : 1830, loss : 0.54836
# Epoch : 1840, loss : 0.54835
# Epoch : 1850, loss : 0.54835
# Epoch : 1860, loss : 0.54834
# Epoch : 1870, loss : 0.54833
# Epoch : 1880, loss : 0.54833
# Epoch : 1890, loss : 0.54832
# Epoch : 1900, loss : 0.54831
# Epoch : 1910, loss : 0.54831
# Epoch : 1920, loss : 0.54830
# Epoch : 1930, loss : 0.54830
# Epoch : 1940, loss : 0.54829
# Epoch : 1950, loss : 0.54828
# Epoch : 1960, loss : 0.54828
# Epoch : 1970, loss : 0.54827
# Epoch : 1980, loss : 0.54827
# Epoch : 1990, loss : 0.54826
# Epoch : 2000, loss : 0.54825
# Epoch : 2010, loss : 0.54825
# Epoch : 2020, loss : 0.54824
# Epoch : 2030, loss : 0.54824
# Epoch : 2040, loss : 0.54823
# Epoch : 2050, loss : 0.54823
# Epoch : 2060, loss : 0.54822
# Epoch : 2070, loss : 0.54822
# Epoch : 2080, loss : 0.54821
# Epoch : 2090, loss : 0.54821
# Epoch : 2100, loss : 0.54820
# Epoch : 2110, loss : 0.54820
# Epoch : 2120, loss : 0.54819
# Epoch : 2130, loss : 0.54819
# Epoch : 2140, loss : 0.54818
# Epoch : 2150, loss : 0.54818
# Epoch : 2160, loss : 0.54817
# Epoch : 2170, loss : 0.54817
# Epoch : 2180, loss : 0.54816
# Epoch : 2190, loss : 0.54816
# Epoch : 2200, loss : 0.54816
# Epoch : 2210, loss : 0.54815
# Epoch : 2220, loss : 0.54815
# Epoch : 2230, loss : 0.54814
# Epoch : 2240, loss : 0.54814
# Epoch : 2250, loss : 0.54813
# Epoch : 2260, loss : 0.54813
# Epoch : 2270, loss : 0.54813
# Epoch : 2280, loss : 0.54812
# Epoch : 2290, loss : 0.54812
# Epoch : 2300, loss : 0.54811
# Epoch : 2310, loss : 0.54811
# Epoch : 2320, loss : 0.54811
# Epoch : 2330, loss : 0.54810
# Epoch : 2340, loss : 0.54810
# Epoch : 2350, loss : 0.54810
# Epoch : 2360, loss : 0.54809
# Epoch : 2370, loss : 0.54809
# Epoch : 2380, loss : 0.54808
# Epoch : 2390, loss : 0.54808
# Epoch : 2400, loss : 0.54808
# Epoch : 2410, loss : 0.54807
# Epoch : 2420, loss : 0.54807
# Epoch : 2430, loss : 0.54807
# Epoch : 2440, loss : 0.54806
# Epoch : 2450, loss : 0.54806
# Epoch : 2460, loss : 0.54806
# Epoch : 2470, loss : 0.54805
# Epoch : 2480, loss : 0.54805
# Epoch : 2490, loss : 0.54805
# Epoch : 2500, loss : 0.54805
# Epoch : 2510, loss : 0.54804
# Epoch : 2520, loss : 0.54804
# Epoch : 2530, loss : 0.54804
# Epoch : 2540, loss : 0.54803
# Epoch : 2550, loss : 0.54803
# Epoch : 2560, loss : 0.54803
# Epoch : 2570, loss : 0.54802
# Epoch : 2580, loss : 0.54802
# Epoch : 2590, loss : 0.54802
# Epoch : 2600, loss : 0.54802
# Epoch : 2610, loss : 0.54801
# Epoch : 2620, loss : 0.54801
# Epoch : 2630, loss : 0.54801
# Epoch : 2640, loss : 0.54800
# Epoch : 2650, loss : 0.54800
# Epoch : 2660, loss : 0.54800
# Epoch : 2670, loss : 0.54800
# Epoch : 2680, loss : 0.54799
# Epoch : 2690, loss : 0.54799
# Epoch : 2700, loss : 0.54799
# Epoch : 2710, loss : 0.54799
# Epoch : 2720, loss : 0.54798
# Epoch : 2730, loss : 0.54798
# Epoch : 2740, loss : 0.54798
# Epoch : 2750, loss : 0.54798
# Epoch : 2760, loss : 0.54797
# Epoch : 2770, loss : 0.54797
# Epoch : 2780, loss : 0.54797
# Epoch : 2790, loss : 0.54797
# Epoch : 2800, loss : 0.54797
# Epoch : 2810, loss : 0.54796
# Epoch : 2820, loss : 0.54796
# Epoch : 2830, loss : 0.54796
# Epoch : 2840, loss : 0.54796
# Epoch : 2850, loss : 0.54795
# Epoch : 2860, loss : 0.54795
# Epoch : 2870, loss : 0.54795
# Epoch : 2880, loss : 0.54795
# Epoch : 2890, loss : 0.54795
# Epoch : 2900, loss : 0.54794
# Epoch : 2910, loss : 0.54794
# Epoch : 2920, loss : 0.54794
# Epoch : 2930, loss : 0.54794
# Epoch : 2940, loss : 0.54794
# Epoch : 2950, loss : 0.54793
# Epoch : 2960, loss : 0.54793
# Epoch : 2970, loss : 0.54793
# Epoch : 2980, loss : 0.54793
# Epoch : 2990, loss : 0.54793
# Epoch : 3000, loss : 0.54792
# Epoch : 3010, loss : 0.54792
# Epoch : 3020, loss : 0.54792
# Epoch : 3030, loss : 0.54792
# Epoch : 3040, loss : 0.54792
# Epoch : 3050, loss : 0.54791
# Epoch : 3060, loss : 0.54791
# Epoch : 3070, loss : 0.54791
# Epoch : 3080, loss : 0.54791
# Epoch : 3090, loss : 0.54791
# Epoch : 3100, loss : 0.54791
# Epoch : 3110, loss : 0.54790
# Epoch : 3120, loss : 0.54790
# Epoch : 3130, loss : 0.54790
# Epoch : 3140, loss : 0.54790
# Epoch : 3150, loss : 0.54790
# Epoch : 3160, loss : 0.54790
# Epoch : 3170, loss : 0.54789
# Epoch : 3180, loss : 0.54789
# Epoch : 3190, loss : 0.54789
# Epoch : 3200, loss : 0.54789
# Epoch : 3210, loss : 0.54789
# Epoch : 3220, loss : 0.54789
# Epoch : 3230, loss : 0.54788
# Epoch : 3240, loss : 0.54788
# Epoch : 3250, loss : 0.54788
# Epoch : 3260, loss : 0.54788
# Epoch : 3270, loss : 0.54788
# Epoch : 3280, loss : 0.54788
# Epoch : 3290, loss : 0.54788
# Epoch : 3300, loss : 0.54787
# Epoch : 3310, loss : 0.54787
# Epoch : 3320, loss : 0.54787
# Epoch : 3330, loss : 0.54787
# Epoch : 3340, loss : 0.54787
# Epoch : 3350, loss : 0.54787
# Epoch : 3360, loss : 0.54787
# Epoch : 3370, loss : 0.54786
# Epoch : 3380, loss : 0.54786
# Epoch : 3390, loss : 0.54786
# Epoch : 3400, loss : 0.54786
# Epoch : 3410, loss : 0.54786
# Epoch : 3420, loss : 0.54786
# Epoch : 3430, loss : 0.54786
# Epoch : 3440, loss : 0.54785
# Epoch : 3450, loss : 0.54785
# Epoch : 3460, loss : 0.54785
# Epoch : 3470, loss : 0.54785
# Epoch : 3480, loss : 0.54785
# Epoch : 3490, loss : 0.54785
# Epoch : 3500, loss : 0.54785
# Epoch : 3510, loss : 0.54785
# Epoch : 3520, loss : 0.54784
# Epoch : 3530, loss : 0.54784
# Epoch : 3540, loss : 0.54784
# Epoch : 3550, loss : 0.54784
# Epoch : 3560, loss : 0.54784
# Epoch : 3570, loss : 0.54784
# Epoch : 3580, loss : 0.54784
# Epoch : 3590, loss : 0.54784
# Epoch : 3600, loss : 0.54784
# Epoch : 3610, loss : 0.54783
# Epoch : 3620, loss : 0.54783
# Epoch : 3630, loss : 0.54783
# Epoch : 3640, loss : 0.54783
# Epoch : 3650, loss : 0.54783
# Epoch : 3660, loss : 0.54783
# Epoch : 3670, loss : 0.54783
# Epoch : 3680, loss : 0.54783
# Epoch : 3690, loss : 0.54783
# Epoch : 3700, loss : 0.54782
# Epoch : 3710, loss : 0.54782
# Epoch : 3720, loss : 0.54782
# Epoch : 3730, loss : 0.54782
# Epoch : 3740, loss : 0.54782
# Epoch : 3750, loss : 0.54782
# Epoch : 3760, loss : 0.54782
# Epoch : 3770, loss : 0.54782
# Epoch : 3780, loss : 0.54782
# Epoch : 3790, loss : 0.54782
# Epoch : 3800, loss : 0.54781
# Epoch : 3810, loss : 0.54781
# Epoch : 3820, loss : 0.54781
# Epoch : 3830, loss : 0.54781
# Epoch : 3840, loss : 0.54781
# Epoch : 3850, loss : 0.54781
# Epoch : 3860, loss : 0.54781
# Epoch : 3870, loss : 0.54781
# Epoch : 3880, loss : 0.54781
# Epoch : 3890, loss : 0.54781
# Epoch : 3900, loss : 0.54780
# Epoch : 3910, loss : 0.54780
# Epoch : 3920, loss : 0.54780
# Epoch : 3930, loss : 0.54780
# Epoch : 3940, loss : 0.54780
# Epoch : 3950, loss : 0.54780
# Epoch : 3960, loss : 0.54780
# Epoch : 3970, loss : 0.54780
# Epoch : 3980, loss : 0.54780
# Epoch : 3990, loss : 0.54780
# Epoch : 4000, loss : 0.54780
# Epoch : 4010, loss : 0.54780
# Epoch : 4020, loss : 0.54779
# Epoch : 4030, loss : 0.54779
# Epoch : 4040, loss : 0.54779
# Epoch : 4050, loss : 0.54779
# Epoch : 4060, loss : 0.54779
# Epoch : 4070, loss : 0.54779
# Epoch : 4080, loss : 0.54779
# Epoch : 4090, loss : 0.54779
# Epoch : 4100, loss : 0.54779
# Epoch : 4110, loss : 0.54779
# Epoch : 4120, loss : 0.54779
# Epoch : 4130, loss : 0.54779
# Epoch : 4140, loss : 0.54778
# Epoch : 4150, loss : 0.54778
# Epoch : 4160, loss : 0.54778
# Epoch : 4170, loss : 0.54778
# Epoch : 4180, loss : 0.54778
# Epoch : 4190, loss : 0.54778
# Epoch : 4200, loss : 0.54778
# Epoch : 4210, loss : 0.54778
# Epoch : 4220, loss : 0.54778
# Epoch : 4230, loss : 0.54778
# Epoch : 4240, loss : 0.54778
# Epoch : 4250, loss : 0.54778
# Epoch : 4260, loss : 0.54778
# Epoch : 4270, loss : 0.54778
# Epoch : 4280, loss : 0.54777
# Epoch : 4290, loss : 0.54777
# Epoch : 4300, loss : 0.54777
# Epoch : 4310, loss : 0.54777
# Epoch : 4320, loss : 0.54777
# Epoch : 4330, loss : 0.54777
# Epoch : 4340, loss : 0.54777
# Epoch : 4350, loss : 0.54777
# Epoch : 4360, loss : 0.54777
# Epoch : 4370, loss : 0.54777
# Epoch : 4380, loss : 0.54777
# Epoch : 4390, loss : 0.54777
# Epoch : 4400, loss : 0.54777
# Epoch : 4410, loss : 0.54777
# Epoch : 4420, loss : 0.54777
# Epoch : 4430, loss : 0.54777
# Epoch : 4440, loss : 0.54776
# Epoch : 4450, loss : 0.54776
# Epoch : 4460, loss : 0.54776
# Epoch : 4470, loss : 0.54776
# Epoch : 4480, loss : 0.54776
# Epoch : 4490, loss : 0.54776
# Epoch : 4500, loss : 0.54776
# Epoch : 4510, loss : 0.54776
# Epoch : 4520, loss : 0.54776
# Epoch : 4530, loss : 0.54776
# Epoch : 4540, loss : 0.54776
# Epoch : 4550, loss : 0.54776
# Epoch : 4560, loss : 0.54776
# Epoch : 4570, loss : 0.54776
# Epoch : 4580, loss : 0.54776
# Epoch : 4590, loss : 0.54776
# Epoch : 4600, loss : 0.54776
# Epoch : 4610, loss : 0.54775
# Epoch : 4620, loss : 0.54775
# Epoch : 4630, loss : 0.54775
# Epoch : 4640, loss : 0.54775
# Epoch : 4650, loss : 0.54775
# Epoch : 4660, loss : 0.54775
# Epoch : 4670, loss : 0.54775
# Epoch : 4680, loss : 0.54775
# Epoch : 4690, loss : 0.54775
# Epoch : 4700, loss : 0.54775
# Epoch : 4710, loss : 0.54775
# Epoch : 4720, loss : 0.54775
# Epoch : 4730, loss : 0.54775
# Epoch : 4740, loss : 0.54775
# Epoch : 4750, loss : 0.54775
# Epoch : 4760, loss : 0.54775
# Epoch : 4770, loss : 0.54775
# Epoch : 4780, loss : 0.54775
# Epoch : 4790, loss : 0.54775
# Epoch : 4800, loss : 0.54774
# Epoch : 4810, loss : 0.54774
# Epoch : 4820, loss : 0.54774
# Epoch : 4830, loss : 0.54774
# Epoch : 4840, loss : 0.54774
# Epoch : 4850, loss : 0.54774
# Epoch : 4860, loss : 0.54774
# Epoch : 4870, loss : 0.54774
# Epoch : 4880, loss : 0.54774
# Epoch : 4890, loss : 0.54774
# Epoch : 4900, loss : 0.54774
# Epoch : 4910, loss : 0.54774
# Epoch : 4920, loss : 0.54774
# Epoch : 4930, loss : 0.54774
# Epoch : 4940, loss : 0.54774
# Epoch : 4950, loss : 0.54774
# Epoch : 4960, loss : 0.54774
# Epoch : 4970, loss : 0.54774
# Epoch : 4980, loss : 0.54774
# Epoch : 4990, loss : 0.54774
# Epoch : 5000, loss : 0.54774
# Epoch : 5010, loss : 0.54774
# Epoch : 5020, loss : 0.54773
# Epoch : 5030, loss : 0.54773
# Epoch : 5040, loss : 0.54773
# Epoch : 5050, loss : 0.54773
# Epoch : 5060, loss : 0.54773
# Epoch : 5070, loss : 0.54773
# Epoch : 5080, loss : 0.54773
# Epoch : 5090, loss : 0.54773
# Epoch : 5100, loss : 0.54773
# Epoch : 5110, loss : 0.54773
# Epoch : 5120, loss : 0.54773
# Epoch : 5130, loss : 0.54773
# Epoch : 5140, loss : 0.54773
# Epoch : 5150, loss : 0.54773
# Epoch : 5160, loss : 0.54773
# Epoch : 5170, loss : 0.54773
# Epoch : 5180, loss : 0.54773
# Epoch : 5190, loss : 0.54773
# Epoch : 5200, loss : 0.54773
# Epoch : 5210, loss : 0.54773
# Epoch : 5220, loss : 0.54773
# Epoch : 5230, loss : 0.54773
# Epoch : 5240, loss : 0.54773
# Epoch : 5250, loss : 0.54773
# Epoch : 5260, loss : 0.54773
# Epoch : 5270, loss : 0.54773
# Epoch : 5280, loss : 0.54772
# Epoch : 5290, loss : 0.54772
# Epoch : 5300, loss : 0.54772
# Epoch : 5310, loss : 0.54772
# Epoch : 5320, loss : 0.54772
# Epoch : 5330, loss : 0.54772
# Epoch : 5340, loss : 0.54772
# Epoch : 5350, loss : 0.54772
# Epoch : 5360, loss : 0.54772
# Epoch : 5370, loss : 0.54772
# Epoch : 5380, loss : 0.54772
# Epoch : 5390, loss : 0.54772
# Epoch : 5400, loss : 0.54772
# Epoch : 5410, loss : 0.54772
# Epoch : 5420, loss : 0.54772
# Epoch : 5430, loss : 0.54772
# Epoch : 5440, loss : 0.54772
# Epoch : 5450, loss : 0.54772
# Epoch : 5460, loss : 0.54772
# Epoch : 5470, loss : 0.54772
# Epoch : 5480, loss : 0.54772
# Epoch : 5490, loss : 0.54772
# Epoch : 5500, loss : 0.54772
# Epoch : 5510, loss : 0.54772
# Epoch : 5520, loss : 0.54772
# Epoch : 5530, loss : 0.54772
# Epoch : 5540, loss : 0.54772
# Epoch : 5550, loss : 0.54772
# Epoch : 5560, loss : 0.54772
# Epoch : 5570, loss : 0.54772
# Epoch : 5580, loss : 0.54771
# Epoch : 5590, loss : 0.54771
# Epoch : 5600, loss : 0.54771
# Epoch : 5610, loss : 0.54771
# Epoch : 5620, loss : 0.54771
# Epoch : 5630, loss : 0.54771
# Epoch : 5640, loss : 0.54771
# Epoch : 5650, loss : 0.54771
# Epoch : 5660, loss : 0.54771
# Epoch : 5670, loss : 0.54771
# Epoch : 5680, loss : 0.54771
# Epoch : 5690, loss : 0.54771
# Epoch : 5700, loss : 0.54771
# Epoch : 5710, loss : 0.54771
# Epoch : 5720, loss : 0.54771
# Epoch : 5730, loss : 0.54771
# Epoch : 5740, loss : 0.54771
# Epoch : 5750, loss : 0.54771
# Epoch : 5760, loss : 0.54771
# Epoch : 5770, loss : 0.54771
# Epoch : 5780, loss : 0.54771
# Epoch : 5790, loss : 0.54771
# Epoch : 5800, loss : 0.54771
# Epoch : 5810, loss : 0.54771
# Epoch : 5820, loss : 0.54771
# Epoch : 5830, loss : 0.54771
# Epoch : 5840, loss : 0.54771
# Epoch : 5850, loss : 0.54771
# Epoch : 5860, loss : 0.54771
# Epoch : 5870, loss : 0.54771
# Epoch : 5880, loss : 0.54771
# Epoch : 5890, loss : 0.54771
# Epoch : 5900, loss : 0.54771
# Epoch : 5910, loss : 0.54771
# Epoch : 5920, loss : 0.54771
# Epoch : 5930, loss : 0.54771
# Epoch : 5940, loss : 0.54771
# Epoch : 5950, loss : 0.54771
# Epoch : 5960, loss : 0.54770
# Epoch : 5970, loss : 0.54770
# Epoch : 5980, loss : 0.54770
# Epoch : 5990, loss : 0.54770
# Epoch : 6000, loss : 0.54770
# Epoch : 6010, loss : 0.54770
# Epoch : 6020, loss : 0.54770
# Epoch : 6030, loss : 0.54770
# Epoch : 6040, loss : 0.54770
# Epoch : 6050, loss : 0.54770
# Epoch : 6060, loss : 0.54770
# Epoch : 6070, loss : 0.54770
# Epoch : 6080, loss : 0.54770
# Epoch : 6090, loss : 0.54770
# Epoch : 6100, loss : 0.54770
# Epoch : 6110, loss : 0.54770
# Epoch : 6120, loss : 0.54770
# Epoch : 6130, loss : 0.54770
# Epoch : 6140, loss : 0.54770
# Epoch : 6150, loss : 0.54770
# Epoch : 6160, loss : 0.54770
# Epoch : 6170, loss : 0.54770
# Epoch : 6180, loss : 0.54770
# Epoch : 6190, loss : 0.54770
# Epoch : 6200, loss : 0.54770
# Epoch : 6210, loss : 0.54770
# Epoch : 6220, loss : 0.54770
# Epoch : 6230, loss : 0.54770
# Epoch : 6240, loss : 0.54770
# Epoch : 6250, loss : 0.54770
# Epoch : 6260, loss : 0.54770
# Epoch : 6270, loss : 0.54770
# Epoch : 6280, loss : 0.54770
# Epoch : 6290, loss : 0.54770
# Epoch : 6300, loss : 0.54770
# Epoch : 6310, loss : 0.54770
# Epoch : 6320, loss : 0.54770
# Epoch : 6330, loss : 0.54770
# Epoch : 6340, loss : 0.54770
# Epoch : 6350, loss : 0.54770
# Epoch : 6360, loss : 0.54770
# Epoch : 6370, loss : 0.54770
# Epoch : 6380, loss : 0.54770
# Epoch : 6390, loss : 0.54770
# Epoch : 6400, loss : 0.54770
# Epoch : 6410, loss : 0.54770
# Epoch : 6420, loss : 0.54770
# Epoch : 6430, loss : 0.54769
# Epoch : 6440, loss : 0.54769
# Epoch : 6450, loss : 0.54769
# Epoch : 6460, loss : 0.54769
# Epoch : 6470, loss : 0.54769
# Epoch : 6480, loss : 0.54769
# Epoch : 6490, loss : 0.54769
# Epoch : 6500, loss : 0.54769
# Epoch : 6510, loss : 0.54769
# Epoch : 6520, loss : 0.54769
# Epoch : 6530, loss : 0.54769
# Epoch : 6540, loss : 0.54769
# Epoch : 6550, loss : 0.54769
# Epoch : 6560, loss : 0.54769
# Epoch : 6570, loss : 0.54769
# Epoch : 6580, loss : 0.54769
# Epoch : 6590, loss : 0.54769
# Epoch : 6600, loss : 0.54769
# Epoch : 6610, loss : 0.54769
# Epoch : 6620, loss : 0.54769
# Epoch : 6630, loss : 0.54769
# Epoch : 6640, loss : 0.54769
# Epoch : 6650, loss : 0.54769
# Epoch : 6660, loss : 0.54769
# Epoch : 6670, loss : 0.54769
# Epoch : 6680, loss : 0.54769
# Epoch : 6690, loss : 0.54769
# Epoch : 6700, loss : 0.54769
# Epoch : 6710, loss : 0.54769
# Epoch : 6720, loss : 0.54769
# Epoch : 6730, loss : 0.54769
# Epoch : 6740, loss : 0.54769
# Epoch : 6750, loss : 0.54769
# Epoch : 6760, loss : 0.54769
# Epoch : 6770, loss : 0.54769
# Epoch : 6780, loss : 0.54769
# Epoch : 6790, loss : 0.54769
# Epoch : 6800, loss : 0.54769
# Epoch : 6810, loss : 0.54769
# Epoch : 6820, loss : 0.54769
# Epoch : 6830, loss : 0.54769
# Epoch : 6840, loss : 0.54769
# Epoch : 6850, loss : 0.54769
# Epoch : 6860, loss : 0.54769
# Epoch : 6870, loss : 0.54769
# Epoch : 6880, loss : 0.54769
# Epoch : 6890, loss : 0.54769
# Epoch : 6900, loss : 0.54769
# Epoch : 6910, loss : 0.54769
# Epoch : 6920, loss : 0.54769
# Epoch : 6930, loss : 0.54769
# Epoch : 6940, loss : 0.54769
# Epoch : 6950, loss : 0.54769
# Epoch : 6960, loss : 0.54769
# Epoch : 6970, loss : 0.54769
# Epoch : 6980, loss : 0.54769
# Epoch : 6990, loss : 0.54769
# Epoch : 7000, loss : 0.54769
# Epoch : 7010, loss : 0.54769
# Epoch : 7020, loss : 0.54769
# Epoch : 7030, loss : 0.54769
# Epoch : 7040, loss : 0.54769
# Epoch : 7050, loss : 0.54769
# Epoch : 7060, loss : 0.54769
# Epoch : 7070, loss : 0.54769
# Epoch : 7080, loss : 0.54769
# Epoch : 7090, loss : 0.54768
# Epoch : 7100, loss : 0.54768
# Epoch : 7110, loss : 0.54768
# Epoch : 7120, loss : 0.54768
# Epoch : 7130, loss : 0.54768
# Epoch : 7140, loss : 0.54768
# Epoch : 7150, loss : 0.54768
# Epoch : 7160, loss : 0.54768
# Epoch : 7170, loss : 0.54768
# Epoch : 7180, loss : 0.54768
# Epoch : 7190, loss : 0.54768
# Epoch : 7200, loss : 0.54768
# Epoch : 7210, loss : 0.54768
# Epoch : 7220, loss : 0.54768
# Epoch : 7230, loss : 0.54768
# Epoch : 7240, loss : 0.54768
# Epoch : 7250, loss : 0.54768
# Epoch : 7260, loss : 0.54768
# Epoch : 7270, loss : 0.54768
# Epoch : 7280, loss : 0.54768
# Epoch : 7290, loss : 0.54768
# Epoch : 7300, loss : 0.54768
# Epoch : 7310, loss : 0.54768
# Epoch : 7320, loss : 0.54768
# Epoch : 7330, loss : 0.54768
# Epoch : 7340, loss : 0.54768
# Epoch : 7350, loss : 0.54768
# Epoch : 7360, loss : 0.54768
# Epoch : 7370, loss : 0.54768
# Epoch : 7380, loss : 0.54768
# Epoch : 7390, loss : 0.54768
# Epoch : 7400, loss : 0.54768
# Epoch : 7410, loss : 0.54768
# Epoch : 7420, loss : 0.54768
# Epoch : 7430, loss : 0.54768
# Epoch : 7440, loss : 0.54768
# Epoch : 7450, loss : 0.54768
# Epoch : 7460, loss : 0.54768
# Epoch : 7470, loss : 0.54768
# Epoch : 7480, loss : 0.54768
# Epoch : 7490, loss : 0.54768
# Epoch : 7500, loss : 0.54768
# Epoch : 7510, loss : 0.54768
# Epoch : 7520, loss : 0.54768
# Epoch : 7530, loss : 0.54768
# Epoch : 7540, loss : 0.54768
# Epoch : 7550, loss : 0.54768
# Epoch : 7560, loss : 0.54768
# Epoch : 7570, loss : 0.54768
# Epoch : 7580, loss : 0.54768
# Epoch : 7590, loss : 0.54768
# Epoch : 7600, loss : 0.54768
# Epoch : 7610, loss : 0.54768
# Epoch : 7620, loss : 0.54768
# Epoch : 7630, loss : 0.54768
# Epoch : 7640, loss : 0.54768
# Epoch : 7650, loss : 0.54768
# Epoch : 7660, loss : 0.54768
# Epoch : 7670, loss : 0.54768
# Epoch : 7680, loss : 0.54768
# Epoch : 7690, loss : 0.54768
# Epoch : 7700, loss : 0.54768
# Epoch : 7710, loss : 0.54768
# Epoch : 7720, loss : 0.54768
# Epoch : 7730, loss : 0.54768
# Epoch : 7740, loss : 0.54768
# Epoch : 7750, loss : 0.54768
# Epoch : 7760, loss : 0.54768
# Epoch : 7770, loss : 0.54768
# Epoch : 7780, loss : 0.54768
# Epoch : 7790, loss : 0.54768
# Epoch : 7800, loss : 0.54768
# Epoch : 7810, loss : 0.54768
# Epoch : 7820, loss : 0.54768
# Epoch : 7830, loss : 0.54768
# Epoch : 7840, loss : 0.54768
# Epoch : 7850, loss : 0.54768
# Epoch : 7860, loss : 0.54768
# Epoch : 7870, loss : 0.54768
# Epoch : 7880, loss : 0.54768
# Epoch : 7890, loss : 0.54768
# Epoch : 7900, loss : 0.54768
# Epoch : 7910, loss : 0.54768
# Epoch : 7920, loss : 0.54768
# Epoch : 7930, loss : 0.54768
# Epoch : 7940, loss : 0.54768
# Epoch : 7950, loss : 0.54768
# Epoch : 7960, loss : 0.54768
# Epoch : 7970, loss : 0.54768
# Epoch : 7980, loss : 0.54768
# Epoch : 7990, loss : 0.54768
# Epoch : 8000, loss : 0.54768
# Epoch : 8010, loss : 0.54768
# Epoch : 8020, loss : 0.54768
# Epoch : 8030, loss : 0.54768
# Epoch : 8040, loss : 0.54768
# Epoch : 8050, loss : 0.54768
# Epoch : 8060, loss : 0.54768
# Epoch : 8070, loss : 0.54768
# Epoch : 8080, loss : 0.54768
# Epoch : 8090, loss : 0.54768
# Epoch : 8100, loss : 0.54768
# Epoch : 8110, loss : 0.54767
# Epoch : 8120, loss : 0.54767
# Epoch : 8130, loss : 0.54767
# Epoch : 8140, loss : 0.54767
# Epoch : 8150, loss : 0.54767
# Epoch : 8160, loss : 0.54767
# Epoch : 8170, loss : 0.54767
# Epoch : 8180, loss : 0.54767
# Epoch : 8190, loss : 0.54767
# Epoch : 8200, loss : 0.54767
# Epoch : 8210, loss : 0.54767
# Epoch : 8220, loss : 0.54767
# Epoch : 8230, loss : 0.54767
# Epoch : 8240, loss : 0.54767
# Epoch : 8250, loss : 0.54767
# Epoch : 8260, loss : 0.54767
# Epoch : 8270, loss : 0.54767
# Epoch : 8280, loss : 0.54767
# Epoch : 8290, loss : 0.54767
# Epoch : 8300, loss : 0.54767
# Epoch : 8310, loss : 0.54767
# Epoch : 8320, loss : 0.54767
# Epoch : 8330, loss : 0.54767
# Epoch : 8340, loss : 0.54767
# Epoch : 8350, loss : 0.54767
# Epoch : 8360, loss : 0.54767
# Epoch : 8370, loss : 0.54767
# Epoch : 8380, loss : 0.54767
# Epoch : 8390, loss : 0.54767
# Epoch : 8400, loss : 0.54767
# Epoch : 8410, loss : 0.54767
# Epoch : 8420, loss : 0.54767
# Epoch : 8430, loss : 0.54767
# Epoch : 8440, loss : 0.54767
# Epoch : 8450, loss : 0.54767
# Epoch : 8460, loss : 0.54767
# Epoch : 8470, loss : 0.54767
# Epoch : 8480, loss : 0.54767
# Epoch : 8490, loss : 0.54767
# Epoch : 8500, loss : 0.54767
# Epoch : 8510, loss : 0.54767
# Epoch : 8520, loss : 0.54767
# Epoch : 8530, loss : 0.54767
# Epoch : 8540, loss : 0.54767
# Epoch : 8550, loss : 0.54767
# Epoch : 8560, loss : 0.54767
# Epoch : 8570, loss : 0.54767
# Epoch : 8580, loss : 0.54767
# Epoch : 8590, loss : 0.54767
# Epoch : 8600, loss : 0.54767
# Epoch : 8610, loss : 0.54767
# Epoch : 8620, loss : 0.54767
# Epoch : 8630, loss : 0.54767
# Epoch : 8640, loss : 0.54767
# Epoch : 8650, loss : 0.54767
# Epoch : 8660, loss : 0.54767
# Epoch : 8670, loss : 0.54767
# Epoch : 8680, loss : 0.54767
# Epoch : 8690, loss : 0.54767
# Epoch : 8700, loss : 0.54767
# Epoch : 8710, loss : 0.54767
# Epoch : 8720, loss : 0.54767
# Epoch : 8730, loss : 0.54767
# Epoch : 8740, loss : 0.54767
# Epoch : 8750, loss : 0.54767
# Epoch : 8760, loss : 0.54767
# Epoch : 8770, loss : 0.54767
# Epoch : 8780, loss : 0.54767
# Epoch : 8790, loss : 0.54767
# Epoch : 8800, loss : 0.54767
# Epoch : 8810, loss : 0.54767
# Epoch : 8820, loss : 0.54767
# Epoch : 8830, loss : 0.54767
# Epoch : 8840, loss : 0.54767
# Epoch : 8850, loss : 0.54767
# Epoch : 8860, loss : 0.54767
# Epoch : 8870, loss : 0.54767
# Epoch : 8880, loss : 0.54767
# Epoch : 8890, loss : 0.54767
# Epoch : 8900, loss : 0.54767
# Epoch : 8910, loss : 0.54767
# Epoch : 8920, loss : 0.54767
# Epoch : 8930, loss : 0.54767
# Epoch : 8940, loss : 0.54767
# Epoch : 8950, loss : 0.54767
# Epoch : 8960, loss : 0.54767
# Epoch : 8970, loss : 0.54767
# Epoch : 8980, loss : 0.54767
# Epoch : 8990, loss : 0.54767
# Epoch : 9000, loss : 0.54767
# Epoch : 9010, loss : 0.54767
# Epoch : 9020, loss : 0.54767
# Epoch : 9030, loss : 0.54767
# Epoch : 9040, loss : 0.54767
# Epoch : 9050, loss : 0.54767
# Epoch : 9060, loss : 0.54767
# Epoch : 9070, loss : 0.54767
# Epoch : 9080, loss : 0.54767
# Epoch : 9090, loss : 0.54767
# Epoch : 9100, loss : 0.54767
# Epoch : 9110, loss : 0.54767
# Epoch : 9120, loss : 0.54767
# Epoch : 9130, loss : 0.54767
# Epoch : 9140, loss : 0.54767
# Epoch : 9150, loss : 0.54767
# Epoch : 9160, loss : 0.54767
# Epoch : 9170, loss : 0.54767
# Epoch : 9180, loss : 0.54767
# Epoch : 9190, loss : 0.54767
# Epoch : 9200, loss : 0.54767
# Epoch : 9210, loss : 0.54767
# Epoch : 9220, loss : 0.54767
# Epoch : 9230, loss : 0.54767
# Epoch : 9240, loss : 0.54767
# Epoch : 9250, loss : 0.54767
# Epoch : 9260, loss : 0.54767
# Epoch : 9270, loss : 0.54767
# Epoch : 9280, loss : 0.54767
# Epoch : 9290, loss : 0.54767
# Epoch : 9300, loss : 0.54767
# Epoch : 9310, loss : 0.54767
# Epoch : 9320, loss : 0.54767
# Epoch : 9330, loss : 0.54767
# Epoch : 9340, loss : 0.54767
# Epoch : 9350, loss : 0.54767
# Epoch : 9360, loss : 0.54767
# Epoch : 9370, loss : 0.54767
# Epoch : 9380, loss : 0.54767
# Epoch : 9390, loss : 0.54767
# Epoch : 9400, loss : 0.54767
# Epoch : 9410, loss : 0.54767
# Epoch : 9420, loss : 0.54767
# Epoch : 9430, loss : 0.54767
# Epoch : 9440, loss : 0.54767
# Epoch : 9450, loss : 0.54767
# Epoch : 9460, loss : 0.54767
# Epoch : 9470, loss : 0.54767
# Epoch : 9480, loss : 0.54767
# Epoch : 9490, loss : 0.54767
# Epoch : 9500, loss : 0.54767
# Epoch : 9510, loss : 0.54767
# Epoch : 9520, loss : 0.54767
# Epoch : 9530, loss : 0.54767
# Epoch : 9540, loss : 0.54767
# Epoch : 9550, loss : 0.54767
# Epoch : 9560, loss : 0.54767
# Epoch : 9570, loss : 0.54767
# Epoch : 9580, loss : 0.54767
# Epoch : 9590, loss : 0.54767
# Epoch : 9600, loss : 0.54767
# Epoch : 9610, loss : 0.54767
# Epoch : 9620, loss : 0.54767
# Epoch : 9630, loss : 0.54767
# Epoch : 9640, loss : 0.54767
# Epoch : 9650, loss : 0.54767
# Epoch : 9660, loss : 0.54767
# Epoch : 9670, loss : 0.54767
# Epoch : 9680, loss : 0.54767
# Epoch : 9690, loss : 0.54767
# Epoch : 9700, loss : 0.54767
# Epoch : 9710, loss : 0.54767
# Epoch : 9720, loss : 0.54767
# Epoch : 9730, loss : 0.54767
# Epoch : 9740, loss : 0.54767
# Epoch : 9750, loss : 0.54767
# Epoch : 9760, loss : 0.54767
# Epoch : 9770, loss : 0.54767
# Epoch : 9780, loss : 0.54767
# Epoch : 9790, loss : 0.54767
# Epoch : 9800, loss : 0.54767
# Epoch : 9810, loss : 0.54767
# Epoch : 9820, loss : 0.54767
# Epoch : 9830, loss : 0.54767
# Epoch : 9840, loss : 0.54767
# Epoch : 9850, loss : 0.54767
# Epoch : 9860, loss : 0.54767
# Epoch : 9870, loss : 0.54767
# Epoch : 9880, loss : 0.54767
# Epoch : 9890, loss : 0.54767
# Epoch : 9900, loss : 0.54767
# Epoch : 9910, loss : 0.54767
# Epoch : 9920, loss : 0.54767
# Epoch : 9930, loss : 0.54767
# Epoch : 9940, loss : 0.54767
# Epoch : 9950, loss : 0.54767
# Epoch : 9960, loss : 0.54767
# Epoch : 9970, loss : 0.54767
# Epoch : 9980, loss : 0.54767
# Epoch : 9990, loss : 0.54767
